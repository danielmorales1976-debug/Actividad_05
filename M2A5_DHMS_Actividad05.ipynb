# %% [markdown]
# <a href="https://colab.research.google.com/github/danielmorales1976-debug/Actividad_05/blob/main/M2A5_DHMS_Actividad05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Logo_Tecmilenio.png](data:image/png;base64,...)

# %% [markdown]
# # **ACTIVIDAD 05**
# ## Uso de estructuras y sentencias de control en Python
#
# **Nombre:** Daniel Horacio Morales Sosa
# **Materia:** Fundamentos y aplicaciones de Inteligencia Artificial
# **Profesor:**  Luis Ariel Vazquez Piña

# %% [markdown]
# ## Objetivo de la actividad
# ###  Implementación de listas, diccionarios y cadenas integrando sentencias de control **if, for, while**

# %% [markdown]
# # **Parte 1**

# %% [markdown]
# * Lista con elementos * Asigna en una lista los valores, en este caso se elabora una lista de paises para su posterior despliegue con print

# %%
paises = ["USA","Mexico","España","Colombia","Francia","Italia"]
print(paises)
# Out:
# ['USA', 'Mexico', 'España', 'Colombia', 'Francia', 'Italia']

# %% [markdown]
# * Agregar elemento en el indice 2 * En este caso a la lista de paises se le indica el indice 2 en donde se agrega el pais India. Al terminar se muestra el resultado

# %%
paises.insert(2,"India")
print(paises)
# Out:
# ['USA', 'Mexico', 'India', 'España', 'Colombia', 'Francia', 'Italia']

# %% [markdown]
# * Agregar elemento al final de la lista * Para agregar un elemento a la lista paises se llama el metodo append que nos ayuda a agregar en este ejemplo a Canada. al mostrar el resultado se observa que esta al final de la lista

# %%
paises.append("Canada")
print(paises)
# Out:
# ['USA', 'Mexico', 'India', 'España', 'Colombia', 'Francia', 'Italia', 'Canada']

# %% [markdown]
# * Cadena de caracteres con tres palabras * En la cadena se agregan las tres palabras separadas por espacios y al sinal se muestra el resultado

# %%
cadena ="Agua es vida"
print(cadena)
# Out:
# Agua es vida

# %% [markdown]
# * Cuenta los caracteres de la **cadena** * Para contar la cantidad de caracteres nos ayudamos mel metodo len

# %%
len(cadena)
# Out:
# 12

# %% [markdown]
# * Guardar en una nueva variable la cadena de caracteres en **Mayusculas** * Declaramos una variable *nueva_cadena* en la cual nos valemos del metodo upper() para poder convertir el contenido de cadena. Al final se muestra el resultado ya con Mayusculas

# %%
nueva_cadena = cadena.upper()
print(nueva_cadena)
# Out:
# AGUA ES VIDA

# %% [markdown]
# * **Diccionario** con cuatro elementos con el indice usando las primeras letras del alfabeto * Declaramos el diccionario de ciudades, para poder indicar el indice lo indicamos con las letras del abecedario seguido de ":" en donde nos valemos de las comillas para asignar el valor con los paises. al final se muestra el resultado

# %%
diccionary_paises2 = {
    "a" : "Mexico",
    "b" : "Argentina",
    "c" : "Brasil",
    "d" : "Colombia",
    "e" : "Chile"
}
print(diccionary_paises2)
# Out:
# {'a': 'Mexico', 'b': 'Argentina', 'c': 'Brasil', 'd': 'Colombia', 'e': 'Chile'}

# %% [markdown]
# * Agregar un **nuevo elemento** al diccionario * al diccionario que ya teniamos le agregamos el indice "f" y posteriormente su valor que en este caso es el pais de "Uruguay"

# %%
diccionary_paises2["f"]="Uruguay"
print(diccionary_paises2)
# Out:
# {'a': 'Mexico', 'b': 'Argentina', 'c': 'Brasil', 'd': 'Colombia', 'e': 'Chile', 'f': 'Uruguay'}

# %% [markdown]
# * **Eliminar** elemento con indice "c" * para eliminar nos apoyamos con el metodo del seguido del nombre del diccionario indicando el indice "c" para eliminar el pais

# %%
del diccionary_paises2["c"]
print(diccionary_paises2)
# Out:
# {'a': 'Mexico', 'b': 'Argentina', 'd': 'Colombia', 'e': 'Chile', 'f': 'Uruguay'}

# %% [markdown]
# * **Conteo** de elementos en el diccionario * para mostrar el conteo de elementos aqui nos apoyamos del metodo *len()* y el diccionario con el cual nos da el resultado de Paises

# %%
len(diccionary_paises2)
# Out:
# 5

# %% [markdown]
# # **Parte 2**

# %% [markdown]
# ### a) Una sala de cine cobra diferentes precios de entrada según la edad de la persona. Si una persona es menor de 3 años, la entrada es gratuita; si tienen entre 3 y 12, el boleto es de 10 pesos; y si son mayores de 12 años, el boleto cuesta 15.00 pesos. Escribe un bucle en el que se solicite a los usuarios su edad y despliegue el costo de la entrada.

# %% [markdown]
# * En este ejercicion me apoye del comando while para generar el bucle indicando la condición de que sea diferente a 0 y dentro se realizan dos comparaciones la primera para los menores de 3 años la segunda para establecer el rango de mayores o igual a 12 y terminando con un else para los que no cumplen ninguna de las dos condiciones

# %%
while (edad := int(input("Indica la edad:"))) != 0 :
  if (edad < 3) :
    print(f"Tu edad es: {edad}.\n - Al ser menor de 3 años la entrada es gratuita")
  elif (edad <= 12) :
    print(f"Tu edad es: {edad}.\n - Al tener entre 3 y 12 años, tu boleto es de 10 pesos")
  else :
    print(f"Tu edad es: {edad}.\n - Tienes mas de 12 años, tu boleto cuesta 15 pesos")
# Out:
# Indica la edad:0

# %% [markdown]
# ### b) Crea un diccionario que contenga la información de una canción (artista, álbum, duración y género) y despliega el contenido de cada elemento (keys, values y tuplas)

# %% [markdown]
# * Para este ejercicio cree un diccionario utilizando como llave o clave el nombre de la cancion y el valor un arreglo que contiene el Artista, Album, duración y genero
# * al final utilice un metodo declarado con *def* el cual contiene el metodo for el cual ayuda a recorrer el directorio mostrando el contenido.

# %%
canciones = {
    "Bohemian Rhapsody": ["Queen","A Night at the Opera","5:55","Art Rock, Pop Rock"],
    "Shape of You": ["Ed Sheeran","Divide","3.53","Pop"],
    "Sound of Silence" : ["Simon and Garfunkel","Sounds of Silence","3:05","Folk pop"],
    "Sweet Caroline" : ["Neil Diamond","3:21","Soft rock"]
}
def mostrar_diccionario(diccionario):
    for clave, valor in diccionario.items():
        print(f"Clave: {clave}")
        print(f"Valor: {valor}")
        print("Tupla:", tuple(valor))
        print()
mostrar_diccionario(canciones)
# Out:
# Clave: Bohemian Rhapsody
# Valor: ['Queen', 'A Night at the Opera', '5:55', 'Art Rock, Pop Rock']
# Tupla: ('Queen', 'A Night at the Opera', '5:55', 'Art Rock, Pop Rock')
#
# Clave: Shape of You
# Valor: ['Ed Sheeran', 'Divide', '3.53', 'Pop']
# Tupla: ('Ed Sheeran', 'Divide', '3.53', 'Pop')
#
# Clave: Sound of Silence
# Valor: ['Simon and Garfunkel', 'Sounds of Silence', '3:05', 'Folk pop']
# Tupla: ('Simon and Garfunkel', 'Sounds of Silence', '3:05', 'Folk pop')
#
# Clave: Sweet Caroline
# Valor: ['Neil Diamond', '3:21', 'Soft rock']
# Tupla: ('Neil Diamond', '3:21', 'Soft rock')
